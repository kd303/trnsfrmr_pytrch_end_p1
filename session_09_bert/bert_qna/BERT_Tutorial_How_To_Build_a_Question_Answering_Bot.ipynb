# %% [markdown]
# <a href="https://colab.research.google.com/github/kd303/trnsfrmr_pytrch_end_p1/blob/main/session_09_bert/bert_qna/BERT_Tutorial_How_To_Build_a_Question_Answering_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERT Tutorial- How To Build a Question Answering Bot
#
# Article by Michel Kana: https://towardsdatascience.com/bert-nlp-how-to-build-a-question-answering-bot-98b1d1594d7b
#
# Code credits to Michel Kana, and Prachur Bhargava, Lead Data Scientist @ Microsoft

# %%
# verify GPU availability
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# install huggingface libraries
# !pip install pytorch-pretrained-bert pytorch-nlp pytorch_transformers
# Out:
# Collecting pytorch-pretrained-bert
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 8.4 MB/s
# Collecting pytorch-nlp
#   Downloading pytorch_nlp-0.5.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 8.7 MB/s
# Collecting pytorch_transformers
#   Downloading pytorch_transformers-1.2.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 63.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (2.23.0)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (1.10.0+cu111)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (2019.12.20)
# Collecting boto3
#   Downloading boto3-1.20.45-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 58.2 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert) (4.62.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.1->pytorch-pretrained-bert) (3.10.0.2)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 51.3 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 48.3 MB/s
# Collecting botocore<1.24.0,>=1.23.45
#   Downloading botocore-1.23.45-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 45.7 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 62.8 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.0,>=1.23.45->boto3->pytorch-pretrained-bert) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.0,>=1.23.45->boto3->pytorch-pretrained-bert) (1.15.0)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 59.1 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->pytorch_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->pytorch_transformers) (1.1.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, sentencepiece, sacremoses, boto3, pytorch-transformers, pytorch-pretrained-bert, pytorch-nlp
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.20.45 botocore-1.23.45 jmespath-0.10.0 pytorch-nlp-0.5.0 pytorch-pretrained-bert-0.6.2 pytorch-transformers-1.2.0 s3transfer-0.5.0 sacremoses-0.0.47 sentencepiece-0.1.96 urllib3-1.25.11

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pytorch_transformers import BertTokenizer, BertConfig, BertModel
from pytorch_transformers import AdamW, BertForQuestionAnswering
from tqdm import tqdm, trange
import pandas as pd
import io
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# BERT imports
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pytorch_pretrained_bert import BertTokenizer, BertConfig
from pytorch_pretrained_bert import BertAdam, BertForSequenceClassification
from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# specify GPU device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla P100-PCIE-16GB'

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
# !wget 'https://raw.githubusercontent.com/nlpyang/pytorch-transformers/master/examples/utils_squad_evaluate.py'
# Out:
# --2022-01-28 16:41:19--  https://raw.githubusercontent.com/nlpyang/pytorch-transformers/master/examples/utils_squad_evaluate.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12493 (12K) [text/plain]
# Saving to: ‘utils_squad_evaluate.py’
#
# utils_squad_evaluat 100%[===================>]  12.20K  --.-KB/s    in 0s
#
# 2022-01-28 16:41:19 (84.0 MB/s) - ‘utils_squad_evaluate.py’ saved [12493/12493]

# %%
# !wget 'https://raw.githubusercontent.com/nlpyang/pytorch-transformers/master/examples/utils_squad.py'

# %%
# !wget 'https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json'
# Out:
# --2022-01-28 16:41:47--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘train-v2.0.json’
#
# train-v2.0.json     100%[===================>]  40.17M   217MB/s    in 0.2s
#
# 2022-01-28 16:41:48 (217 MB/s) - ‘train-v2.0.json’ saved [42123633/42123633]

# %%
# !ls /drive/My\ Drive/Medium
# Out:
# ls: cannot access '/drive/My Drive/Medium': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/train-v2.0.json /content/drive/MyDrive/bert_data

# %%
# !cp /content/utils_squad.py /content/drive/MyDrive/bert_data

# %%
# !cp /content/utils_squad_evaluate.py /content/drive/MyDrive/bert_data

# %%
## !mkdir /content/drive/MyDrive/bert_data

# %%
# !ls /content/drive/MyDrive/bert_data
# Out:
# train-v2.0.json  utils_squad_evaluate.py  utils_squad.py

# %%
import sys
sys.path.append('/content/drive/MyDrive/bert_data')

# %%
from utils_squad import (read_squad_examples, convert_examples_to_features,
                         RawResult, write_predictions,
                         RawResultExtended, write_predictions_extended)
from utils_squad_evaluate import EVAL_OPTS, main as evaluate_on_squad, plot_pr_curve

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
input_file = '/content/drive/MyDrive/bert_data/train-v2.0.json'
examples = read_squad_examples(input_file=input_file,
                                is_training=True,
                                version_2_with_negative=True)

# %%
examples[:5]
# Out:
# [qas_id: 56be85543aeaaa14008c9063, question_text: When did Beyonce start becoming popular?, doc_tokens: [Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".], start_position: 39, end_position: 42,
#  qas_id: 56be85543aeaaa14008c9065, question_text: What areas did Beyonce compete in when she was growing up?, doc_tokens: [Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".], start_position: 28, end_position: 30,
#  qas_id: 56be85543aeaaa14008c9066, question_text: When did Beyonce leave Destiny's Child and become a solo singer?, doc_tokens: [Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".], start_position: 82, end_position: 82,
#  qas_id: 56bf6b0f3aeaaa14008c9601, question_text: In what city and state did Beyonce  grow up? , doc_tokens: [Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".], start_position: 22, end_position: 23,
#  qas_id: 56bf6b0f3aeaaa14008c9602, question_text: In which decade did Beyonce become famous?, doc_tokens: [Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".], start_position: 41, end_position: 42]

# %%
train_data = pd.DataFrame.from_records([vars(example) for example in examples])
train_data.head()
# Out:
#                      qas_id  ... is_impossible
# 0  56be85543aeaaa14008c9063  ...         False
# 1  56be85543aeaaa14008c9065  ...         False
# 2  56be85543aeaaa14008c9066  ...         False
# 3  56bf6b0f3aeaaa14008c9601  ...         False
# 4  56bf6b0f3aeaaa14008c9602  ...         False
#
# [5 rows x 7 columns]

# %%
sample = train_data.sample(frac=1).head(1)
context = sample.doc_tokens.values
train_data[train_data.doc_tokens.values==context]
# Out:
#                           qas_id  ... is_impossible
# 100094  572ba77b34ae481900deaec7  ...         False
# 100095  572ba77b34ae481900deaec8  ...         False
# 100096  572ba77b34ae481900deaec9  ...         False
# 100097  5acd7bf407355d001abf4430  ...          True
# 100098  5acd7bf407355d001abf4431  ...          True
# 100099  5acd7bf407355d001abf4432  ...          True
# 100100  5acd7bf407355d001abf4433  ...          True
# 100101  5acd7bf407355d001abf4434  ...          True
#
# [8 rows x 7 columns]

# %%
import random
def print_squad_sample(train_data, line_length=14, separator_length=120):
  sample = train_data.sample(frac=1).head(1)
  context = sample.doc_tokens.values
  print('='*separator_length)
  print('CONTEXT: ')
  print('='*separator_length)
  lines = [' '.join(context[0][idx:idx+line_length]) for idx in range(0, len(context[0]), line_length)]
  for l in lines:
      print(l)
  print('='*separator_length)
  questions = train_data[train_data.doc_tokens.values==context]
  print('QUESTION:', ' '*(3*separator_length//4), 'ANSWER:')
  for idx, row in questions.iterrows():
    question = row.question_text
    answer = row.orig_answer_text
    print(question, ' '*(3*separator_length//4-len(question)+9), (answer if answer else 'No awnser found'))

# %%
print_squad_sample(train_data)
# Out:
# ========================================================================================================================
# CONTEXT:
# ========================================================================================================================
# English Dominican mysticism in the late medieval period differed from European strands of it
# in that, whereas European Dominican mysticism tended to concentrate on ecstatic experiences of union
# with the divine, English Dominican mysticism's ultimate focus was on a crucial dynamic in
# one's personal relationship with God. This was an essential moral imitation of the Savior
# as an ideal for religious change, and as the means for reformation of humanity's
# nature as an image of divinity. This type of mysticism carried with it four
# elements. First, spiritually it emulated the moral essence of Christ's life. Second, there was
# a connection linking moral emulation of Christ's life and humanity's disposition as images of
# the divine. Third, English Dominican mysticism focused on an embodied spirituality with a structured
# love of fellow men at its center. Finally, the supreme aspiration of this mysticism
# was either an ethical or an actual union with God.
# ========================================================================================================================
# QUESTION:                                                                                            ANSWER:
# What did European mysticism concentrate on that English mysticism didn't?                            ecstatic experiences of union with the divine
# English mysticism was composed of how many elements?                                                 four
# What is one element of English Dominican mysticism?                                                  it emulated the moral essence of Christ's life
# What was the focus of English Dominican mysticism?                                                   one's personal relationship with God
# What did European mysticism and English mysticism both concentrate on?                               No awnser found
# What was not a focus for English Dominican mysticism?                                                No awnser found
# Which mysticism was composed of 5 elements?                                                          No awnser found
# What was not an image of divinity?                                                                   No awnser found
# What was not ethical or an actual union of God?                                                      No awnser found

# %%
len
# Out:
# <function len>

# %%
train_data['paragraph_len'] = train_data['doc_tokens'].apply(len)
train_data['question_len'] = train_data['question_text'].apply(len)
train_data.sample(frac=1).head(5)
# Out:
#                          qas_id  ... question_len
# 12831  56df25da3277331400b4d9b1  ...           48
# 26719  56fa81d38f12f31900630165  ...           54
# 65350  5a1e07ce3de3f40018b26453  ...          116
# 7455   5a591d523e1742001a15cf9e  ...           60
# 75807  5727db08ff5b5019007d96f4  ...           72
#
# [5 rows x 9 columns]

# %%
max_seq_length = 256
print("Percentage of context's less than max_seq_length = %s%%" % (len([l for l in train_data['paragraph_len'] if l <= max_seq_length])/len(train_data) * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d7f80711648e> in <module>()
#       1 max_seq_length = 256
# ----> 2 print("Percentage of context's less than max_seq_length = %s%%" % (len([l for l in train_data['paragraph_len'] if l <= max_seq_length])/len(train_data) * 100))
#
# NameError: name 'train_data' is not defined

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
doc_stride = 128
max_seq_length = 256
max_query_length = 64
# batch size of 64 if RAM available.
batch_size = 32 ## 16 // 64

# %%
cached_features_file = '/content/drive/MyDrive/bert_data/cached_features.json'

# %%
if not os.path.exists(cached_features_file):
  features = convert_examples_to_features(examples=examples,
                                        tokenizer=tokenizer,
                                        max_seq_length=max_seq_length,
                                        doc_stride=doc_stride,
                                        max_query_length=max_query_length,
                                        is_training=True)
  torch.save(features, cached_features_file)
else:
  features = torch.load(cached_features_file)

# %%
def set_seed(seed=42):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
# Convert to Tensors and build dataset
all_input_ids = torch.tensor([f.input_ids for f in features], dtype=torch.long)
all_input_mask = torch.tensor([f.input_mask for f in features], dtype=torch.long)
all_segment_ids = torch.tensor([f.segment_ids for f in features], dtype=torch.long)
all_cls_index = torch.tensor([f.cls_index for f in features], dtype=torch.long)
all_p_mask = torch.tensor([f.p_mask for f in features], dtype=torch.float)

all_start_positions = torch.tensor([f.start_position for f in features], dtype=torch.long)
all_end_positions = torch.tensor([f.end_position for f in features], dtype=torch.long)
dataset = TensorDataset(all_input_ids, all_input_mask, all_segment_ids,
                        all_start_positions, all_end_positions,
                        all_cls_index, all_p_mask)

# %%
train_sampler = RandomSampler(dataset)
train_dataloader = DataLoader(dataset, sampler=train_sampler, batch_size=batch_size, drop_last=True)

# %%
import glob
checkpoints = sorted(glob.glob('/content/drive/MyDrive/bert_data/model-ckp/checkpoint*-[0-9]*'))

# %%
def to_list(tensor):
    return tensor.detach().cpu().tolist()

# %%
print(checkpoints)
# Out:
# []

# %%
if len(checkpoints) > 0:
  global_step = checkpoints[-1].split('-')[-1]
  ckpt_name = '/content/drive/MyDrive/bert_data/model-ckp/checkpoint-{}'.format(global_step)
  print("Loading model from checkpoint %s" % ckpt_name)
  model = BertForQuestionAnswering.from_pretrained(ckpt_name)
  train_loss_set_ckpt = torch.load(ckpt_name + '/training_loss.pt')
  train_loss_set = to_list(train_loss_set_ckpt)
  tr_loss = train_loss_set[-1]
else:
  global_step = 0
  train_loss_set = []
  tr_loss = 0.0
  model = BertForQuestionAnswering.from_pretrained('bert-base-uncased')

model.cuda()
# Out:
# BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
param_optimizer = list(model.named_parameters())
print(param_optimizer[-2])
print(param_optimizer[-1])
# Out:
# ('qa_outputs.weight', Parameter containing:
# tensor([[ 0.0226,  0.0073, -0.0102,  ...,  0.0167, -0.0311, -0.0112],
#         [ 0.0243, -0.0141, -0.0268,  ..., -0.0019, -0.0300,  0.0087]],
#        device='cuda:0', requires_grad=True))
# ('qa_outputs.bias', Parameter containing:
# tensor([0., 0.], device='cuda:0', requires_grad=True))

# %%
learning_rate = 5e-5
adam_epsilon=1e-8
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
    ]
optimizer = AdamW(optimizer_grouped_parameters, lr=learning_rate, eps=adam_epsilon)

# %%
batch_size = 16 ## 16 // 64

# %%
num_train_epochs = 1

print("***** Running training *****")
print("  Num examples = %d" % len(dataset))
print("  Num Epochs = %d" % num_train_epochs)
print("  Batch size = %d" % batch_size)
print("  Total optimization steps = %d" % (len(train_dataloader) // num_train_epochs))

model.zero_grad()
train_iterator = trange(num_train_epochs, desc="Epoch")
set_seed()

for _ in train_iterator:
    epoch_iterator = tqdm(train_dataloader, desc="Iteration")
    for step, batch in enumerate(epoch_iterator):
      if step < global_step + 1:
        continue

      model.train()
      batch = tuple(t.to(device) for t in batch)

      inputs = {'input_ids':       batch[0],
                'attention_mask':  batch[1], 
                'token_type_ids':  batch[2],  
                'start_positions': batch[3], 
                'end_positions':   batch[4]}

      outputs = model(**inputs)

      loss = outputs[0]
      train_loss_set.append(loss)
      loss.backward()
      torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

      tr_loss += loss.item()
      optimizer.step()
      model.zero_grad()
      global_step += 1
    
      if global_step % 1000 == 0:
        print("Train loss: {}".format(tr_loss/global_step))
        output_dir = '/content/drive/MyDrive/bert_data/model-ckp/checkpoint-{}'.format(global_step)
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        model_to_save = model.module if hasattr(model, 'module') else model  # Take care of distributed/parallel training
        model_to_save.save_pretrained(output_dir)
        torch.save(torch.tensor(train_loss_set), os.path.join(output_dir, 'training_loss.pt'))
        print("Saving model checkpoint to %s" % output_dir)
# Out:
# ***** Running training *****
#   Num examples = 144262
#   Num Epochs = 1
#   Batch size = 32
#   Total optimization steps = 4508
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/4508 [00:00<?, ?it/s]
# Iteration:   3%|▎         | 145/4508 [00:00<00:03, 1443.89it/s]
# Iteration:   6%|▋         | 290/4508 [00:00<00:02, 1437.29it/s]
# Iteration:  10%|▉         | 434/4508 [00:00<00:02, 1409.51it/s]
# Iteration:  13%|█▎        | 581/4508 [00:00<00:02, 1429.76it/s]
# Iteration:  16%|█▌        | 730/4508 [00:00<00:02, 1448.95it/s]
# Iteration:  19%|█▉        | 875/4508 [00:00<00:02, 1446.91it/s]
# Iteration:  23%|██▎       | 1020/4508 [00:16<02:08, 27.16it/s]
# Iteration:  23%|██▎       | 1021/4508 [00:17<02:17, 25.37it/s]
# Iteration:  23%|██▎       | 1021/4508 [00:37<02:17, 25.37it/s]
# Iteration:  23%|██▎       | 1045/4508 [00:37<06:51,  8.41it/s]
# Iteration:  23%|██▎       | 1046/4508 [00:38<07:06,  8.11it/s]
# Iteration:  23%|██▎       | 1046/4508 [00:57<07:06,  8.11it/s]
# Iteration:  24%|██▎       | 1069/4508 [00:58<13:43,  4.18it/s]
# Iteration:  24%|██▎       | 1070/4508 [00:59<14:04,  4.07it/s]
# Iteration:  24%|██▎       | 1070/4508 [01:17<14:04,  4.07it/s]
# Iteration:  31%|███▏      | 1412/4508 [05:49<43:56,  1.17it/s]
# Iteration:  31%|███▏      | 1413/4508 [05:50<43:55,  1.17it/s]
# Iteration:  31%|███▏      | 1414/4508 [05:51<43:53,  1.17it/s]
# Iteration:  31%|███▏      | 1415/4508 [05:52<43:54,  1.17it/s]
# Iteration:  31%|███▏      | 1416/4508 [05:53<43:54,  1.17it/s]
# Iteration:  31%|███▏      | 1417/4508 [05:54<43:51,  1.17it/s]
# Iteration:  31%|███▏      | 1418/4508 [05:55<43:53,  1.17it/s]
# Iteration:  31%|███▏      | 1419/4508 [05:55<43:50,  1.17it/s]
# Iteration:  31%|███▏      | 1420/4508 [05:56<43:49,  1.17it/s]
# Iteration:  32%|███▏      | 1421/4508 [05:57<43:48,  1.17it/s]
# Iteration:  32%|███▏      | 1422/4508 [05:58<43:48,  1.17it/s]
# Iteration:  32%|███▏      | 1423/4508 [05:59<43:49,  1.17it/s]
# Iteration:  32%|███▏      | 1424/4508 [06:00<43:54,  1.17it/s]
# Iteration:  32%|███▏      | 1425/4508 [06:01<43:50,  1.17it/s]
# Iteration:  32%|███▏      | 1426/4508 [06:01<43:49,  1.17it/s]
# Iteration:  32%|███▏      | 1427/4508 [06:02<43:51,  1.17it/s]
# Iteration:  32%|███▏      | 1428/4508 [06:03<43:48,  1.17it/s]
# Iteration:  32%|███▏      | 1429/4508 [06:04<43:44,  1.17it/s]
# Iteration:  32%|███▏      | 1430/4508 [06:05<43:43,  1.17it/s]
# Iteration:  32%|███▏      | 1431/4508 [06:06<43:40,  1.17it/s]
# Iteration:  32%|███▏      | 1432/4508 [06:07<43:44,  1.17it/s]
# Iteration:  32%|███▏      | 1433/4508 [06:07<43:39,  1.17it/s]
# Iteration:  32%|███▏      | 1434/4508 [06:08<43:38,  1.17it/s]
# Iteration:  32%|███▏      | 1435/4508 [06:09<43:38,  1.17it/s]
# Iteration:  32%|███▏      | 1436/4508 [06:10<43:40,  1.17it/s]
# Iteration:  32%|███▏      | 1437/4508 [06:11<43:48,  1.17it/s]
# Iteration:  32%|███▏      | 1438/4508 [06:12<43:42,  1.17it/s]
# Iteration:  32%|███▏      | 1439/4508 [06:12<43:35,  1.17it/s]
# Iteration:  32%|███▏      | 1440/4508 [06:13<43:36,  1.17it/s]
# Iteration:  32%|███▏      | 1441/4508 [06:14<43:40,  1.17it/s]
# Iteration:  32%|███▏      | 1442/4508 [06:15<43:39,  1.17it/s]
# Iteration:  32%|███▏      | 1443/4508 [06:16<43:37,  1.17it/s]
# Iteration:  32%|███▏      | 1444/4508 [06:17<43:36,  1.17it/s]
# Iteration:  32%|███▏      | 1445/4508 [06:18<43:34,  1.17it/s]
# Iteration:  32%|███▏      | 1446/4508 [06:18<43:27,  1.17it/s]
# Iteration:  32%|███▏      | 1447/4508 [06:19<43:31,  1.17it/s]
# Iteration:  32%|███▏      | 1448/4508 [06:20<43:31,  1.17it/s]
# Iteration:  32%|███▏      | 1449/4508 [06:21<43:30,  1.17it/s]
# Iteration:  32%|███▏      | 1450/4508 [06:22<43:29,  1.17it/s]
# Iteration:  32%|███▏      | 1451/4508 [06:23<43:23,  1.17it/s]
# Iteration:  32%|███▏      | 1452/4508 [06:24<43:21,  1.17it/s]
# Iteration:  32%|███▏      | 1453/4508 [06:24<43:24,  1.17it/s]
# Iteration:  32%|███▏      | 1454/4508 [06:25<43:25,  1.17it/s]
# Iteration:  32%|███▏      | 1455/4508 [06:26<43:23,  1.17it/s]
# Iteration:  32%|███▏      | 1456/4508 [06:27<43:20,  1.17it/s]
# Iteration:  32%|███▏      | 1457/4508 [06:28<43:21,  1.17it/s]
# Iteration:  32%|███▏      | 1458/4508 [06:29<43:19,  1.17it/s]
# Iteration:  32%|███▏      | 1459/4508 [06:30<43:20,  1.17it/s]
# Iteration:  32%|███▏      | 1460/4508 [06:30<43:15,  1.17it/s]
# Iteration:  32%|███▏      | 1461/4508 [06:31<43:13,  1.18it/s]
# Iteration:  32%|███▏      | 1462/4508 [06:32<43:13,  1.17it/s]
# Iteration:  32%|███▏      | 1463/4508 [06:33<43:20,  1.17it/s]
# Iteration:  32%|███▏      | 1464/4508 [06:34<43:18,  1.17it/s]
# Iteration:  32%|███▏      | 1465/4508 [06:35<43:16,  1.17it/s]
# Iteration:  33%|███▎      | 1466/4508 [06:36<43:09,  1.17it/s]
# Iteration:  33%|███▎      | 1467/4508 [06:36<43:10,  1.17it/s]
# Iteration:  33%|███▎      | 1468/4508 [06:37<43:12,  1.17it/s]
# Iteration:  33%|███▎      | 1469/4508 [06:38<43:12,  1.17it/s]
# Iteration:  33%|███▎      | 1470/4508 [06:39<43:06,  1.17it/s]
# Iteration:  33%|███▎      | 1471/4508 [06:40<43:06,  1.17it/s]
# Iteration:  33%|███▎      | 1472/4508 [06:41<43:05,  1.17it/s]
# Iteration:  33%|███▎      | 1473/4508 [06:41<43:07,  1.17it/s]
# Iteration:  33%|███▎      | 1474/4508 [06:42<43:05,  1.17it/s]
# Iteration:  33%|███▎      | 1475/4508 [06:43<43:03,  1.17it/s]
# Iteration:  33%|███▎      | 1476/4508 [06:44<43:07,  1.17it/s]
# Iteration:  33%|███▎      | 1477/4508 [06:45<43:07,  1.17it/s]
# Iteration:  33%|███▎      | 1478/4508 [06:46<43:04,  1.17it/s]
# Iteration:  33%|███▎      | 1479/4508 [06:47<43:02,  1.17it/s]
# Iteration:  33%|███▎      | 1480/4508 [06:47<43:00,  1.17it/s]
# Iteration:  33%|███▎      | 1481/4508 [06:48<42:58,  1.17it/s]
# Iteration:  33%|███▎      | 1482/4508 [06:49<42:58,  1.17it/s]
# Iteration:  33%|███▎      | 1483/4508 [06:50<42:55,  1.17it/s]
# Iteration:  33%|███▎      | 1484/4508 [06:51<42:49,  1.18it/s]
# Iteration:  33%|███▎      | 1485/4508 [06:52<42:54,  1.17it/s]
# Iteration:  33%|███▎      | 1486/4508 [06:53<42:53,  1.17it/s]
# Iteration:  33%|███▎      | 1487/4508 [06:53<42:57,  1.17it/s]
# Iteration:  33%|███▎      | 1488/4508 [06:54<42:57,  1.17it/s]
# Iteration:  43%|████▎     | 1916/4508 [13:00<36:56,  1.17it/s]
# Iteration:  43%|████▎     | 1917/4508 [13:00<36:53,  1.17it/s]
# Iteration:  43%|████▎     | 1918/4508 [13:01<36:51,  1.17it/s]
# Iteration:  43%|████▎     | 1919/4508 [13:02<36:49,  1.17it/s]
# Iteration:  43%|████▎     | 1920/4508 [13:03<36:54,  1.17it/s]
# ...
# Iteration:  94%|█████████▍| 4256/4508 [46:25<03:35,  1.17it/s]
# Iteration:  94%|█████████▍| 4257/4508 [46:25<03:34,  1.17it/s]
# Iteration:  94%|█████████▍| 4258/4508 [46:26<03:33,  1.17it/s]
# Iteration:  94%|█████████▍| 4259/4508 [46:27<03:32,  1.17it/s]
# Iteration:  94%|█████████▍| 4260/4508 [46:28<03:32,  1.17it/s]
# Iteration:  95%|█████████▍| 4261/4508 [46:29<03:30,  1.17it/s]
# Iteration:  95%|█████████▍| 4262/4508 [46:30<03:29,  1.17it/s]
# Iteration:  95%|█████████▍| 4263/4508 [46:31<03:29,  1.17it/s]
# Iteration:  95%|█████████▍| 4264/4508 [46:31<03:28,  1.17it/s]
# Iteration:  95%|█████████▍| 4265/4508 [46:32<03:27,  1.17it/s]
# Iteration:  95%|█████████▍| 4266/4508 [46:33<03:26,  1.17it/s]
# Iteration:  95%|█████████▍| 4267/4508 [46:34<03:25,  1.17it/s]
# Iteration:  95%|█████████▍| 4268/4508 [46:35<03:24,  1.17it/s]
# Iteration:  95%|█████████▍| 4269/4508 [46:36<03:24,  1.17it/s]
# Iteration:  95%|█████████▍| 4270/4508 [46:37<03:23,  1.17it/s]
# Iteration:  95%|█████████▍| 4271/4508 [46:37<03:22,  1.17it/s]
# Iteration:  95%|█████████▍| 4272/4508 [46:38<03:21,  1.17it/s]
# Iteration:  95%|█████████▍| 4273/4508 [46:39<03:20,  1.17it/s]
# Iteration:  95%|█████████▍| 4274/4508 [46:40<03:20,  1.17it/s]
# Iteration:  95%|█████████▍| 4275/4508 [46:41<03:19,  1.17it/s]
# Iteration:  95%|█████████▍| 4276/4508 [46:42<03:18,  1.17it/s]
# Iteration:  95%|█████████▍| 4277/4508 [46:43<03:17,  1.17it/s]
# Iteration:  95%|█████████▍| 4278/4508 [46:43<03:16,  1.17it/s]
# Iteration:  95%|█████████▍| 4279/4508 [46:44<03:15,  1.17it/s]
# Iteration:  95%|█████████▍| 4280/4508 [46:45<03:14,  1.17it/s]
# Iteration:  95%|█████████▍| 4281/4508 [46:46<03:13,  1.17it/s]
# Iteration:  95%|█████████▍| 4282/4508 [46:47<03:12,  1.17it/s]
# Iteration:  95%|█████████▌| 4283/4508 [46:48<03:12,  1.17it/s]
# Iteration:  95%|█████████▌| 4284/4508 [46:49<03:11,  1.17it/s]
# Iteration:  95%|█████████▌| 4285/4508 [46:49<03:10,  1.17it/s]
# Iteration:  95%|█████████▌| 4286/4508 [46:50<03:09,  1.17it/s]
# Iteration:  95%|█████████▌| 4287/4508 [46:51<03:08,  1.17it/s]
# Iteration:  95%|█████████▌| 4288/4508 [46:52<03:08,  1.17it/s]
# Iteration:  95%|█████████▌| 4289/4508 [46:53<03:06,  1.17it/s]
# Iteration:  95%|█████████▌| 4290/4508 [46:54<03:05,  1.17it/s]
# Iteration:  95%|█████████▌| 4291/4508 [46:55<03:05,  1.17it/s]
# Iteration:  95%|█████████▌| 4292/4508 [46:55<03:04,  1.17it/s]
# Iteration:  95%|█████████▌| 4293/4508 [46:56<03:03,  1.17it/s]
# Iteration:  95%|█████████▌| 4294/4508 [46:57<03:02,  1.17it/s]
# Iteration:  95%|█████████▌| 4295/4508 [46:58<03:01,  1.17it/s]
# Iteration:  95%|█████████▌| 4296/4508 [46:59<03:01,  1.17it/s]
# Iteration:  95%|█████████▌| 4297/4508 [47:00<03:00,  1.17it/s]
# Iteration:  95%|█████████▌| 4298/4508 [47:00<02:59,  1.17it/s]
# Iteration:  95%|█████████▌| 4299/4508 [47:01<02:59,  1.17it/s]
# Iteration:  95%|█████████▌| 4300/4508 [47:02<02:58,  1.17it/s]
# Iteration:  95%|█████████▌| 4301/4508 [47:03<02:57,  1.17it/s]
# Iteration:  95%|█████████▌| 4302/4508 [47:04<02:56,  1.17it/s]
# Iteration:  95%|█████████▌| 4303/4508 [47:05<02:55,  1.17it/s]
# Iteration:  95%|█████████▌| 4304/4508 [47:06<02:54,  1.17it/s]
# Iteration:  95%|█████████▌| 4305/4508 [47:06<02:53,  1.17it/s]
# Iteration:  96%|█████████▌| 4306/4508 [47:07<02:52,  1.17it/s]
# Iteration:  96%|█████████▌| 4307/4508 [47:08<02:51,  1.17it/s]
# Iteration:  96%|█████████▌| 4308/4508 [47:09<02:51,  1.17it/s]
# Iteration:  96%|█████████▌| 4309/4508 [47:10<02:49,  1.17it/s]
# Iteration:  96%|█████████▌| 4310/4508 [47:11<02:49,  1.17it/s]
# Iteration:  96%|█████████▌| 4311/4508 [47:12<02:48,  1.17it/s]
# Iteration:  96%|█████████▌| 4312/4508 [47:12<02:47,  1.17it/s]
# Iteration:  96%|█████████▌| 4313/4508 [47:13<02:46,  1.17it/s]
# Iteration:  96%|█████████▌| 4314/4508 [47:14<02:45,  1.17it/s]
# Iteration:  96%|█████████▌| 4315/4508 [47:15<02:45,  1.17it/s]
# Iteration:  96%|█████████▌| 4316/4508 [47:16<02:44,  1.17it/s]
# Iteration:  96%|█████████▌| 4317/4508 [47:17<02:43,  1.17it/s]
# Iteration:  96%|█████████▌| 4318/4508 [47:18<02:42,  1.17it/s]
# Iteration:  96%|█████████▌| 4319/4508 [47:18<02:41,  1.17it/s]
# Iteration:  96%|█████████▌| 4320/4508 [47:19<02:40,  1.17it/s]
# Iteration:  96%|█████████▌| 4321/4508 [47:20<02:39,  1.17it/s]
# Iteration:  96%|█████████▌| 4322/4508 [47:21<02:38,  1.17it/s]
# Iteration:  96%|█████████▌| 4323/4508 [47:22<02:37,  1.17it/s]
# Iteration:  96%|█████████▌| 4324/4508 [47:23<02:36,  1.17it/s]
# Iteration:  96%|█████████▌| 4325/4508 [47:24<02:36,  1.17it/s]
# Iteration:  96%|█████████▌| 4326/4508 [47:24<02:35,  1.17it/s]
# Iteration:  96%|█████████▌| 4327/4508 [47:25<02:34,  1.17it/s]
# Iteration:  96%|█████████▌| 4328/4508 [47:26<02:33,  1.17it/s]
# Iteration:  96%|█████████▌| 4329/4508 [47:27<02:32,  1.17it/s]
# Iteration:  96%|█████████▌| 4330/4508 [47:28<02:32,  1.17it/s]
# Iteration:  96%|█████████▌| 4331/4508 [47:29<02:31,  1.17it/s]
# Iteration:  96%|█████████▌| 4332/4508 [47:30<02:30,  1.17it/s]
# Iteration:  96%|█████████▌| 4333/4508 [47:30<02:29,  1.17it/s]
# Iteration:  96%|█████████▌| 4334/4508 [47:31<02:28,  1.17it/s]
# Iteration:  96%|█████████▌| 4335/4508 [47:32<02:27,  1.17it/s]
# Iteration:  96%|█████████▌| 4336/4508 [47:33<02:27,  1.17it/s]
# Iteration:  96%|█████████▌| 4337/4508 [47:34<02:26,  1.17it/s]
# Iteration:  96%|█████████▌| 4338/4508 [47:35<02:25,  1.17it/s]
# Iteration:  96%|█████████▋| 4339/4508 [47:36<02:24,  1.17it/s]
# Iteration:  96%|█████████▋| 4340/4508 [47:36<02:23,  1.17it/s]
# Iteration:  96%|█████████▋| 4341/4508 [47:37<02:22,  1.17it/s]
# Iteration:  96%|█████████▋| 4342/4508 [47:38<02:21,  1.17it/s]
# Iteration:  96%|█████████▋| 4343/4508 [47:39<02:21,  1.17it/s]
# Iteration:  96%|█████████▋| 4344/4508 [47:40<02:20,  1.17it/s]
# Iteration:  96%|█████████▋| 4345/4508 [47:41<02:19,  1.17it/s]
# Iteration:  96%|█████████▋| 4346/4508 [47:42<02:18,  1.17it/s]
# Iteration:  96%|█████████▋| 4347/4508 [47:42<02:17,  1.17it/s]
# Iteration:  96%|█████████▋| 4348/4508 [47:43<02:16,  1.17it/s]
# Iteration:  96%|█████████▋| 4349/4508 [47:44<02:15,  1.17it/s]
# Iteration:  96%|█████████▋| 4350/4508 [47:45<02:14,  1.17it/s]
# Iteration:  97%|█████████▋| 4351/4508 [47:46<02:14,  1.17it/s]
# Iteration:  97%|█████████▋| 4352/4508 [47:47<02:13,  1.17it/s]
# Iteration:  97%|█████████▋| 4353/4508 [47:47<02:12,  1.17it/s]
# Iteration:  97%|█████████▋| 4354/4508 [47:48<02:11,  1.17it/s]
# Iteration:  97%|█████████▋| 4355/4508 [47:49<02:10,  1.17it/s]
# Iteration:  97%|█████████▋| 4356/4508 [47:50<02:09,  1.17it/s]
# Iteration:  97%|█████████▋| 4357/4508 [47:51<02:08,  1.17it/s]
# Iteration:  97%|█████████▋| 4358/4508 [47:52<02:07,  1.17it/s]
# Iteration:  97%|█████████▋| 4359/4508 [47:53<02:07,  1.17it/s]
# Iteration:  97%|█████████▋| 4360/4508 [47:53<02:06,  1.17it/s]
# Iteration:  97%|█████████▋| 4361/4508 [47:54<02:05,  1.17it/s]
# Iteration:  97%|█████████▋| 4362/4508 [47:55<02:05,  1.17it/s]
# Iteration:  97%|█████████▋| 4363/4508 [47:56<02:03,  1.17it/s]
# Iteration:  97%|█████████▋| 4364/4508 [47:57<02:03,  1.17it/s]
# Iteration:  97%|█████████▋| 4365/4508 [47:58<02:02,  1.17it/s]
# Iteration:  97%|█████████▋| 4366/4508 [47:59<02:01,  1.17it/s]
# Iteration:  97%|█████████▋| 4367/4508 [47:59<02:00,  1.17it/s]
# Iteration:  97%|█████████▋| 4368/4508 [48:00<01:59,  1.17it/s]
# Iteration:  97%|█████████▋| 4369/4508 [48:01<01:58,  1.17it/s]
# Iteration:  97%|█████████▋| 4370/4508 [48:02<01:58,  1.17it/s]
# Iteration:  97%|█████████▋| 4371/4508 [48:03<01:57,  1.17it/s]
# Iteration:  97%|█████████▋| 4372/4508 [48:04<01:56,  1.17it/s]
# Iteration:  97%|█████████▋| 4373/4508 [48:05<01:55,  1.17it/s]
# Iteration:  97%|█████████▋| 4374/4508 [48:05<01:54,  1.17it/s]
# Iteration:  97%|█████████▋| 4375/4508 [48:06<01:53,  1.17it/s]
# Iteration:  97%|█████████▋| 4376/4508 [48:07<01:53,  1.17it/s]
# Iteration:  97%|█████████▋| 4377/4508 [48:08<01:52,  1.17it/s]
# Iteration:  97%|█████████▋| 4378/4508 [48:09<01:51,  1.17it/s]
# Iteration:  97%|█████████▋| 4379/4508 [48:10<01:50,  1.17it/s]
# Iteration:  97%|█████████▋| 4380/4508 [48:11<01:49,  1.17it/s]
# Iteration:  97%|█████████▋| 4381/4508 [48:11<01:48,  1.17it/s]
# Iteration:  97%|█████████▋| 4382/4508 [48:12<01:47,  1.17it/s]
# Iteration:  97%|█████████▋| 4383/4508 [48:13<01:46,  1.17it/s]
# Iteration:  97%|█████████▋| 4384/4508 [48:14<01:45,  1.17it/s]
# Iteration:  97%|█████████▋| 4385/4508 [48:15<01:45,  1.17it/s]
# Iteration:  97%|█████████▋| 4386/4508 [48:16<01:44,  1.17it/s]
# Iteration:  97%|█████████▋| 4387/4508 [48:17<01:43,  1.17it/s]
# Iteration:  97%|█████████▋| 4388/4508 [48:17<01:42,  1.17it/s]
# Iteration:  97%|█████████▋| 4389/4508 [48:18<01:41,  1.17it/s]
# Iteration:  97%|█████████▋| 4390/4508 [48:19<01:40,  1.17it/s]
# Iteration:  97%|█████████▋| 4391/4508 [48:20<01:40,  1.17it/s]
# Iteration:  97%|█████████▋| 4392/4508 [48:21<01:39,  1.17it/s]
# Iteration:  97%|█████████▋| 4393/4508 [48:22<01:38,  1.17it/s]
# Iteration:  97%|█████████▋| 4394/4508 [48:23<01:37,  1.17it/s]
# Iteration:  97%|█████████▋| 4395/4508 [48:23<01:36,  1.17it/s]
# Iteration:  98%|█████████▊| 4396/4508 [48:24<01:35,  1.17it/s]
# Iteration:  98%|█████████▊| 4397/4508 [48:25<01:34,  1.17it/s]
# Iteration:  98%|█████████▊| 4398/4508 [48:26<01:34,  1.17it/s]
# Iteration:  98%|█████████▊| 4399/4508 [48:27<01:33,  1.17it/s]
# Iteration:  98%|█████████▊| 4400/4508 [48:28<01:32,  1.17it/s]
# Iteration:  98%|█████████▊| 4401/4508 [48:29<01:31,  1.17it/s]
# Iteration:  98%|█████████▊| 4402/4508 [48:29<01:30,  1.17it/s]
# Iteration:  98%|█████████▊| 4403/4508 [48:30<01:29,  1.17it/s]
# Iteration:  98%|█████████▊| 4404/4508 [48:31<01:28,  1.17it/s]
# Iteration:  98%|█████████▊| 4405/4508 [48:32<01:27,  1.17it/s]
# Iteration:  98%|█████████▊| 4406/4508 [48:33<01:27,  1.17it/s]
# Iteration:  98%|█████████▊| 4407/4508 [48:34<01:26,  1.17it/s]
# Iteration:  98%|█████████▊| 4408/4508 [48:35<01:25,  1.17it/s]
# Iteration:  98%|█████████▊| 4409/4508 [48:35<01:24,  1.17it/s]
# Iteration:  98%|█████████▊| 4410/4508 [48:36<01:23,  1.17it/s]
# Iteration:  98%|█████████▊| 4411/4508 [48:37<01:22,  1.17it/s]
# Iteration:  98%|█████████▊| 4412/4508 [48:38<01:21,  1.17it/s]
# Iteration:  98%|█████████▊| 4413/4508 [48:39<01:21,  1.17it/s]
# Iteration:  98%|█████████▊| 4414/4508 [48:40<01:20,  1.17it/s]
# Iteration:  98%|█████████▊| 4415/4508 [48:40<01:19,  1.17it/s]
# Iteration:  98%|█████████▊| 4416/4508 [48:41<01:18,  1.17it/s]
# Iteration:  98%|█████████▊| 4417/4508 [48:42<01:17,  1.17it/s]
# Iteration:  98%|█████████▊| 4418/4508 [48:43<01:16,  1.17it/s]
# Iteration:  98%|█████████▊| 4419/4508 [48:44<01:16,  1.17it/s]
# Iteration:  98%|█████████▊| 4420/4508 [48:45<01:15,  1.17it/s]
# Iteration:  98%|█████████▊| 4421/4508 [48:46<01:14,  1.17it/s]
# Iteration:  98%|█████████▊| 4422/4508 [48:46<01:13,  1.17it/s]
# Iteration:  98%|█████████▊| 4423/4508 [48:47<01:12,  1.17it/s]
# Iteration:  98%|█████████▊| 4424/4508 [48:48<01:11,  1.17it/s]
# Iteration:  98%|█████████▊| 4425/4508 [48:49<01:11,  1.17it/s]
# Iteration:  98%|█████████▊| 4426/4508 [48:50<01:10,  1.17it/s]
# Iteration:  98%|█████████▊| 4427/4508 [48:51<01:09,  1.17it/s]
# Iteration:  98%|█████████▊| 4428/4508 [48:52<01:08,  1.17it/s]
# Iteration:  98%|█████████▊| 4429/4508 [48:52<01:07,  1.17it/s]
# Iteration:  98%|█████████▊| 4430/4508 [48:53<01:06,  1.17it/s]
# Iteration:  98%|█████████▊| 4431/4508 [48:54<01:05,  1.17it/s]
# Iteration:  98%|█████████▊| 4432/4508 [48:55<01:04,  1.17it/s]
# Iteration:  98%|█████████▊| 4433/4508 [48:56<01:04,  1.17it/s]
# Iteration:  98%|█████████▊| 4434/4508 [48:57<01:03,  1.17it/s]
# Iteration:  98%|█████████▊| 4435/4508 [48:58<01:02,  1.17it/s]
# Iteration:  98%|█████████▊| 4436/4508 [48:58<01:01,  1.17it/s]
# Iteration:  98%|█████████▊| 4437/4508 [48:59<01:00,  1.17it/s]
# Iteration:  98%|█████████▊| 4438/4508 [49:00<00:59,  1.17it/s]
# Iteration:  99%|█████████▉| 4477/4508 [49:33<00:26,  1.17it/s]
# Iteration:  99%|█████████▉| 4478/4508 [49:34<00:25,  1.17it/s]
# Iteration:  99%|█████████▉| 4479/4508 [49:35<00:24,  1.17it/s]
# Iteration:  99%|█████████▉| 4480/4508 [49:36<00:23,  1.17it/s]
# Iteration:  99%|█████████▉| 4481/4508 [49:37<00:23,  1.17it/s]
# Iteration:  99%|█████████▉| 4482/4508 [49:38<00:22,  1.17it/s]
# Iteration:  99%|█████████▉| 4483/4508 [49:39<00:21,  1.17it/s]
# Iteration:  99%|█████████▉| 4484/4508 [49:39<00:20,  1.17it/s]
# Iteration:  99%|█████████▉| 4485/4508 [49:40<00:19,  1.17it/s]
# Iteration: 100%|█████████▉| 4486/4508 [49:41<00:18,  1.17it/s]
# Iteration: 100%|█████████▉| 4487/4508 [49:42<00:17,  1.17it/s]
# Iteration: 100%|█████████▉| 4488/4508 [49:43<00:17,  1.17it/s]
# Iteration: 100%|█████████▉| 4489/4508 [49:44<00:16,  1.17it/s]
# Iteration: 100%|█████████▉| 4490/4508 [49:45<00:15,  1.17it/s]
# Iteration: 100%|█████████▉| 4491/4508 [49:45<00:14,  1.17it/s]
# Iteration: 100%|█████████▉| 4492/4508 [49:46<00:13,  1.17it/s]
# Iteration: 100%|█████████▉| 4493/4508 [49:47<00:12,  1.17it/s]
# Iteration: 100%|█████████▉| 4494/4508 [49:48<00:11,  1.17it/s]
# Iteration: 100%|█████████▉| 4495/4508 [49:49<00:11,  1.17it/s]
# Iteration: 100%|█████████▉| 4496/4508 [49:50<00:10,  1.17it/s]
# Iteration: 100%|█████████▉| 4497/4508 [49:51<00:09,  1.17it/s]
# Iteration: 100%|█████████▉| 4498/4508 [49:51<00:08,  1.17it/s]
# Iteration: 100%|█████████▉| 4499/4508 [49:52<00:07,  1.17it/s]
# Iteration: 100%|█████████▉| 4500/4508 [49:53<00:06,  1.17it/s]
# Iteration: 100%|█████████▉| 4501/4508 [49:54<00:05,  1.17it/s]
# Iteration: 100%|█████████▉| 4502/4508 [49:55<00:05,  1.17it/s]
# Iteration: 100%|█████████▉| 4503/4508 [49:56<00:04,  1.17it/s]
# Iteration: 100%|█████████▉| 4504/4508 [49:57<00:03,  1.17it/s]
# Iteration: 100%|█████████▉| 4505/4508 [49:57<00:02,  1.17it/s]
# Iteration: 100%|█████████▉| 4506/4508 [49:58<00:01,  1.17it/s]
# Iteration: 100%|█████████▉| 4507/4508 [49:59<00:00,  1.17it/s]
# Iteration: 100%|██████████| 4508/4508 [50:00<00:00,  1.50it/s]
# Epoch: 100%|██████████| 1/1 [50:00<00:00, 3000.47s/it]

# %%
output_dir = '/content/drive/MyDrive/bert_data/chkpnt-final'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
model_to_save = model.module if hasattr(model, 'module') else model
model_to_save.save_pretrained(output_dir)

# %%
# !cd /content/drive/MyDrive/bert_data/

# %%
# !cp /content/dev-v2.0.json /content/drive/MyDrive/bert_data/

# %%
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Out:
# --2022-01-28 18:31:28--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4370528 (4.2M) [application/json]
# Saving to: ‘dev-v2.0.json’
#
# dev-v2.0.json       100%[===================>]   4.17M  --.-KB/s    in 0.05s
#
# 2022-01-28 18:31:28 (85.9 MB/s) - ‘dev-v2.0.json’ saved [4370528/4370528]

# %%
train_loss_set_ckpt = torch.load('/content/drive/MyDrive/bert_data/model-ckp/checkpoint-4000/training_loss.pt')
train_loss_set = to_list(train_loss_set_ckpt)

# %%
plt.figure(figsize=(15,8))
plt.title("Training loss")
plt.xlabel("Batch")
plt.ylabel("Loss")
plt.plot(train_loss_set)
plt.show()

# %% [markdown]
# **Load test dataset**

# %%
input_file = '/content/drive/MyDrive/bert_data/dev-v2.0.json'
val_examples = read_squad_examples(input_file=input_file,
                                is_training=False,
                                version_2_with_negative=True)
doc_stride = 128
max_seq_length = 256
max_query_length = 64
cached_features_file = '/content/drive/MyDrive/bert_data/cache_validation'

# Cache features for faster loading
if not os.path.exists(cached_features_file):
  features = convert_examples_to_features(examples=val_examples,
                                        tokenizer=tokenizer,
                                        max_seq_length=max_seq_length,
                                        doc_stride=doc_stride,
                                        max_query_length=max_query_length,
                                        is_training=False)
  torch.save(features, cached_features_file)
else:
  features = torch.load(cached_features_file)

# %%
# Convert to Tensors and build dataset
all_input_ids = torch.tensor([f.input_ids for f in features], dtype=torch.long)
all_input_mask = torch.tensor([f.input_mask for f in features], dtype=torch.long)
all_segment_ids = torch.tensor([f.segment_ids for f in features], dtype=torch.long)
all_cls_index = torch.tensor([f.cls_index for f in features], dtype=torch.long)
all_p_mask = torch.tensor([f.p_mask for f in features], dtype=torch.float)

all_example_index = torch.arange(all_input_ids.size(0), dtype=torch.long)
dataset = TensorDataset(all_input_ids, all_input_mask, all_segment_ids,
                        all_example_index, all_cls_index, all_p_mask)

# %%
validation_sampler = SequentialSampler(dataset)
validation_dataloader = DataLoader(dataset, sampler=validation_sampler, batch_size=batch_size, drop_last=True)

# %% [markdown]
# **Evaluate test dataset**

# %%
def evaluate(model, tokenizer):
  print("***** Running evaluation *****")
  print("  Num examples = %d" % len(dataset))
  print("  Batch size = %d" % batch_size)
  all_results = []
  predict_file = '/content/drive/MyDrive/bert_data/dev-v2.0.json'
  for batch in tqdm(validation_dataloader, desc="Evaluating", miniters=100, mininterval=5.0):
    model.eval()
    batch = tuple(t.to(device) for t in batch)
    with torch.no_grad():
      inputs = {'input_ids':      batch[0],
                'attention_mask': batch[1],
                'token_type_ids': batch[2]
                }
      example_indices = batch[3]
      outputs = model(**inputs)

    for i, example_index in enumerate(example_indices):
      eval_feature = features[example_index.item()]
      unique_id = int(eval_feature.unique_id)

      result = RawResult(unique_id    = unique_id,
                         start_logits = to_list(outputs[0][i]),
                         end_logits   = to_list(outputs[1][i]))
      all_results.append(result)

  # Compute predictions
  output_prediction_file = "/content/drive/MyDrive/bert_data/predictions.json"
  output_nbest_file = "/content/drive/MyDrive/bert_data/nbest_predictions.json"
  output_null_log_odds_file = "/content/drive/MyDrive/bert_data/null_odds.json"
  output_dir = "/content/drive/MyDrive/bert_data/predict_results"

  write_predictions(val_examples, features, all_results, 10,
                  30, True, output_prediction_file,
                  output_nbest_file, output_null_log_odds_file, False,
                  True, 0.0)

  # Evaluate with the official SQuAD script
  evaluate_options = EVAL_OPTS(data_file=predict_file,
                               pred_file=output_prediction_file,
                               na_prob_file=output_null_log_odds_file,
                               out_image_dir=None)
  results = evaluate_on_squad(evaluate_options)
  return results

# %%
results = evaluate(model, tokenizer)
# Out:
# ***** Running evaluation *****
#   Num examples = 13600
#   Batch size = 32
# Evaluating: 100%|██████████| 425/425 [02:01<00:00,  3.50it/s]
# {
#   "exact": 70.3697464836183,
#   "f1": 73.58668968300192,
#   "total": 11873,
#   "HasAns_exact": 64.49055330634278,
#   "HasAns_f1": 70.93366508203107,
#   "HasAns_total": 5928,
#   "NoAns_exact": 76.23212783851976,
#   "NoAns_f1": 76.23212783851976,
#   "NoAns_total": 5945,
#   "best_exact": 70.54661837783206,
#   "best_exact_thresh": -0.3960533142089844,
#   "best_f1": 73.61606612222818,
#   "best_f1_thresh": -0.23991966247558594
# }

# %%
import json
results_json = []
for k in enumerate(results.keys()):
  result_dict = {k[1] : results[k[1]]}
  results_json.append(result_dict)
print(results_json)
with open('results.json', 'w') as f:
  json.dump(results_json, f)
# Out:
# [{'exact': 70.3697464836183}, {'f1': 73.58668968300192}, {'total': 11873}, {'HasAns_exact': 64.49055330634278}, {'HasAns_f1': 70.93366508203107}, {'HasAns_total': 5928}, {'NoAns_exact': 76.23212783851976}, {'NoAns_f1': 76.23212783851976}, {'NoAns_total': 5945}, {'best_exact': 70.54661837783206}, {'best_exact_thresh': -0.3960533142089844}, {'best_f1': 73.61606612222818}, {'best_f1_thresh': -0.23991966247558594}]

# %% [markdown]
# **Evaluate on any text**

# %%
# print predictions vs actuals
prediction_file = '/content/drive/MyDrive/bert_data/predictions.json'
with open(prediction_file, "r", encoding='utf-8') as reader:
 pred_data = json.load(reader)
 print(type(pred_data))
 for entry in pred_data:
   for sq_example in val_examples:
     if sq_example.qas_id == entry:
       print(sq_example.qas_id, 'pred :', pred_data[entry], 'actual : ', sq_example.orig_answer_text)
       break

# %%
for example in val_examples:
  # print(example)
  print(example.qas_id,example.question_text, example.orig_answer_text)
# Out:
# Streaming output truncated to the last 5000 lines.
# qas_id: 56e1aff7cd28a01900c67a69, question_text: What fixed set of factors determine the actions of a deterministic Turing machine, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 56e1aff7cd28a01900c67a69 What fixed set of factors determine the actions of a deterministic Turing machine None
# qas_id: 56e1aff7cd28a01900c67a6a, question_text: What is the term used to identify a deterministic Turing machine that has additional random bits?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 56e1aff7cd28a01900c67a6a What is the term used to identify a deterministic Turing machine that has additional random bits? None
# qas_id: 56e1aff7cd28a01900c67a6b, question_text: What type of Turing machine is capable of multiple actions and extends into a variety of computational paths?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 56e1aff7cd28a01900c67a6b What type of Turing machine is capable of multiple actions and extends into a variety of computational paths? None
# qas_id: 56e1aff7cd28a01900c67a6c, question_text: What is the term given to algorithms that utilize random bits?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 56e1aff7cd28a01900c67a6c What is the term given to algorithms that utilize random bits? None
# qas_id: 5ad546c75b96ef001a10ac0e, question_text: What uses a flexible set of rules to determine its future actions?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 5ad546c75b96ef001a10ac0e What uses a flexible set of rules to determine its future actions? None
# qas_id: 5ad546c75b96ef001a10ac0f, question_text: What is a deterministic Turing machine with an extra supply of random ribbons?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 5ad546c75b96ef001a10ac0f What is a deterministic Turing machine with an extra supply of random ribbons? None
# qas_id: 5ad546c75b96ef001a10ac10, question_text: What does not often help algorithms solve problems more efficiently?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 5ad546c75b96ef001a10ac10 What does not often help algorithms solve problems more efficiently? None
# qas_id: 5ad546c75b96ef001a10ac11, question_text: Which machine allows the machine to have multiple possible past actions from a given state?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 5ad546c75b96ef001a10ac11 Which machine allows the machine to have multiple possible past actions from a given state? None
# qas_id: 5ad546c75b96ef001a10ac12, question_text: How is one way that one should not view non-determinism?, doc_tokens: [A deterministic Turing machine is the most basic Turing machine, which uses a fixed set of rules to determine its future actions. A probabilistic Turing machine is a deterministic Turing machine with an extra supply of random bits. The ability to make probabilistic decisions often helps algorithms solve problems more efficiently. Algorithms that use random bits are called randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a theoretically interesting abstract machine that gives rise to particularly interesting complexity classes. For examples, see non-deterministic algorithm.]
# 5ad546c75b96ef001a10ac12 How is one way that one should not view non-determinism? None
# qas_id: 56e1b00ce3433e140042309e, question_text: Turing machines are commonly employed to define what? , doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 56e1b00ce3433e140042309e Turing machines are commonly employed to define what?  None
# qas_id: 56e1b00ce3433e140042309f, question_text: What are two factors that directly effect how powerful a Turing machine may or may not be?, doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 56e1b00ce3433e140042309f What are two factors that directly effect how powerful a Turing machine may or may not be? None
# qas_id: 56e1b00ce3433e14004230a1, question_text: In the determination of complexity classes, what are two examples of types of Turing machines?, doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 56e1b00ce3433e14004230a1 In the determination of complexity classes, what are two examples of types of Turing machines? None
# qas_id: 5ad545545b96ef001a10ac06, question_text: What are many types of Turing machines not used for?, doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 5ad545545b96ef001a10ac06 What are many types of Turing machines not used for? None
# qas_id: 5ad545545b96ef001a10ac07, question_text: What are three factors that directly effect how powerful a Turing machine may or may not be?, doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 5ad545545b96ef001a10ac07 What are three factors that directly effect how powerful a Turing machine may or may not be? None
# qas_id: 5ad545545b96ef001a10ac08, question_text: What machines are not equally powerful in principle?, doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 5ad545545b96ef001a10ac08 What machines are not equally powerful in principle? None
# qas_id: 5ad545545b96ef001a10ac09, question_text: What may not be more powerful than others when the resources of time or space of considered?, doc_tokens: [Many types of Turing machines are used to define complexity classes, such as deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources (such as time or space) are bounded, some of these may be more powerful than others.]
# 5ad545545b96ef001a10ac09 What may not be more powerful than others when the resources of time or space of considered? None
# qas_id: 56e1b169cd28a01900c67a72, question_text: What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 56e1b169cd28a01900c67a72 What is an example of a machine model that deviates from a generally accepted multi-tape Turing machine? None
# qas_id: 56e1b169cd28a01900c67a73, question_text: In considering Turing machines and alternate variables, what measurement left unaffected by conversion between machine models? , doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 56e1b169cd28a01900c67a73 In considering Turing machines and alternate variables, what measurement left unaffected by conversion between machine models?  None
# qas_id: 56e1b169cd28a01900c67a74, question_text: What two resources commonly consumed by alternate models are typically known to vary?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 56e1b169cd28a01900c67a74 What two resources commonly consumed by alternate models are typically known to vary? None
# qas_id: 56e1b169cd28a01900c67a75, question_text: What commonality do alternate machine models, such as random access machines, share with Turing machines?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 56e1b169cd28a01900c67a75 What commonality do alternate machine models, such as random access machines, share with Turing machines? None
# qas_id: 5ad547945b96ef001a10ac18, question_text: What is not an example of a machine model that deviates from a generally accepted multi-tape Turing machine?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 5ad547945b96ef001a10ac18 What is not an example of a machine model that deviates from a generally accepted multi-tape Turing machine? None
# qas_id: 5ad547945b96ef001a10ac19, question_text: What measurement is affected by conversion between machine models?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 5ad547945b96ef001a10ac19 What measurement is affected by conversion between machine models? None
# qas_id: 5ad547945b96ef001a10ac1a, question_text: What two resources are uncommonly consumed by alternate models and are typically known to vary?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 5ad547945b96ef001a10ac1a What two resources are uncommonly consumed by alternate models and are typically known to vary? None
# qas_id: 5ad547945b96ef001a10ac1b, question_text: What do all these models not have in common?, doc_tokens: [Many machine models different from the standard multi-tape Turing machines have been proposed in the literature, for example random access machines. Perhaps surprisingly, each of these models can be converted to another without providing any extra computational power. The time and memory consumption of these alternate models may vary. What all these models have in common is that the machines operate deterministically.]
# 5ad547945b96ef001a10ac1b What do all these models not have in common? None
# qas_id: 56e1b355e3433e14004230b0, question_text: What type of Turing machine can be characterized by checking multiple possibilities at the same time?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 56e1b355e3433e14004230b0 What type of Turing machine can be characterized by checking multiple possibilities at the same time? None
# qas_id: 56e1b355e3433e14004230b1, question_text: What often affects or facilitates ease of analysis in computational problems?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 56e1b355e3433e14004230b1 What often affects or facilitates ease of analysis in computational problems? None
# qas_id: 56e1b355e3433e14004230b2, question_text: A non-deterministic Turing machine has the ability to capture what facet of useful analysis?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 56e1b355e3433e14004230b2 A non-deterministic Turing machine has the ability to capture what facet of useful analysis? None
# qas_id: 56e1b355e3433e14004230b3, question_text: What is the most critical resource in the analysis of computational problems associated with non-deterministic Turing machines?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 56e1b355e3433e14004230b3 What is the most critical resource in the analysis of computational problems associated with non-deterministic Turing machines? None
# qas_id: 5ad5489b5b96ef001a10ac2a, question_text: What is harder to analyze in terms of more unusual resources?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 5ad5489b5b96ef001a10ac2a What is harder to analyze in terms of more unusual resources? None
# qas_id: 5ad5489b5b96ef001a10ac2b, question_text: What type of machine is a computational model that is not allowed to branch out to check many different possibilities at once?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 5ad5489b5b96ef001a10ac2b What type of machine is a computational model that is not allowed to branch out to check many different possibilities at once? None
# qas_id: 5ad5489b5b96ef001a10ac2c, question_text: What has a lot to do with how we physically want to compute algorithms?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 5ad5489b5b96ef001a10ac2c What has a lot to do with how we physically want to compute algorithms? None
# qas_id: 5ad5489b5b96ef001a10ac2d, question_text: What machine's branching does not exactly capture many of the mathematical models we want to analyze?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 5ad5489b5b96ef001a10ac2d What machine's branching does not exactly capture many of the mathematical models we want to analyze? None
# qas_id: 5ad5489b5b96ef001a10ac2e, question_text: What is the least critical resource in the analysis of computational problems associated with non-deterministic Turing machines?, doc_tokens: [However, some computational problems are easier to analyze in terms of more unusual resources. For example, a non-deterministic Turing machine is a computational model that is allowed to branch out to check many different possibilities at once. The non-deterministic Turing machine has very little to do with how we physically want to compute algorithms, but its branching exactly captures many of the mathematical models we want to analyze, so that non-deterministic time is a very important resource in analyzing computational problems.]
# 5ad5489b5b96ef001a10ac2e What is the least critical resource in the analysis of computational problems associated with non-deterministic Turing machines? None
# qas_id: 56e1b62ecd28a01900c67aa3, question_text: The time required to output an answer on a deterministic Turing machine is expressed as what?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 56e1b62ecd28a01900c67aa3 The time required to output an answer on a deterministic Turing machine is expressed as what? None
# qas_id: 56e1b62ecd28a01900c67aa4, question_text: Complexity theory classifies problems based on what primary attribute?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 56e1b62ecd28a01900c67aa4 Complexity theory classifies problems based on what primary attribute? None
# qas_id: 56e1b62ecd28a01900c67aa5, question_text: What is the expression used to identify any given series of problems capable of being solved within time on a deterministic Turing machine?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 56e1b62ecd28a01900c67aa5 What is the expression used to identify any given series of problems capable of being solved within time on a deterministic Turing machine? None
# qas_id: 56e1b62ecd28a01900c67aa6, question_text: What is the most critical resource measured to in assessing the determination of a Turing machine's ability to solve any given set of problems?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 56e1b62ecd28a01900c67aa6 What is the most critical resource measured to in assessing the determination of a Turing machine's ability to solve any given set of problems? None
# qas_id: 5ad54a375b96ef001a10ac48, question_text: What is not used for a precise definition of what it means to solve a problem using a given amount of time and space?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 5ad54a375b96ef001a10ac48 What is not used for a precise definition of what it means to solve a problem using a given amount of time and space? None
# qas_id: 5ad54a375b96ef001a10ac49, question_text: How is Turing machine M said not to operate?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 5ad54a375b96ef001a10ac49 How is Turing machine M said not to operate? None
# qas_id: 5ad54a375b96ef001a10ac4a, question_text: What is the expression used to identify any given series of solutions capable of being solved within time on a deterministic Turing machine?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 5ad54a375b96ef001a10ac4a What is the expression used to identify any given series of solutions capable of being solved within time on a deterministic Turing machine? None
# qas_id: 5ad54a375b96ef001a10ac4b, question_text: What is the least critical resource measured in assessing the determination of a Turing machine's ability to solve any given set of problems?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 5ad54a375b96ef001a10ac4b What is the least critical resource measured in assessing the determination of a Turing machine's ability to solve any given set of problems? None
# qas_id: 5ad54a375b96ef001a10ac4c, question_text: How can decision problem B be solved in time x(f)?, doc_tokens: [For a precise definition of what it means to solve a problem using a given amount of time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n). A decision problem A can be solved in time f(n) if there exists a Turing machine operating in time f(n) that solves the problem. Since complexity theory is interested in classifying problems based on their difficulty, one defines sets of problems based on some criteria. For instance, the set of problems solvable within time f(n) on a deterministic Turing machine is then denoted by DTIME(f(n)).]
# 5ad54a375b96ef001a10ac4c How can decision problem B be solved in time x(f)? None
# qas_id: 56e1b754cd28a01900c67abc, question_text: Time and space are both examples of what type of resource?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 56e1b754cd28a01900c67abc Time and space are both examples of what type of resource? None
# qas_id: 56e1b754cd28a01900c67abd, question_text: A complexity resource can also be described as what other type of resource?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 56e1b754cd28a01900c67abd A complexity resource can also be described as what other type of resource? None
# qas_id: 56e1b754cd28a01900c67abe, question_text: What is typically used to broadly define complexity measures?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 56e1b754cd28a01900c67abe What is typically used to broadly define complexity measures? None
# qas_id: 56e1b754cd28a01900c67abf, question_text: Communication complexity is an example of what type of measure?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 56e1b754cd28a01900c67abf Communication complexity is an example of what type of measure? None
# qas_id: 56e1b754cd28a01900c67ac0, question_text: Decision tree is an example of what type of measure?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 56e1b754cd28a01900c67ac0 Decision tree is an example of what type of measure? None
# qas_id: 5ad54b035b96ef001a10ac52, question_text: What can not be made for space requirements?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 5ad54b035b96ef001a10ac52 What can not be made for space requirements? None
# qas_id: 5ad54b035b96ef001a10ac53, question_text: What are the least well known complexity resources?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 5ad54b035b96ef001a10ac53 What are the least well known complexity resources? None
# qas_id: 5ad54b035b96ef001a10ac54, question_text: How are complexity measures generally not defined?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 5ad54b035b96ef001a10ac54 How are complexity measures generally not defined? None
# qas_id: 5ad54b035b96ef001a10ac55, question_text: What are other complexity measures not used in complexity theory?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 5ad54b035b96ef001a10ac55 What are other complexity measures not used in complexity theory? None
# qas_id: 5ad54b035b96ef001a10ac56, question_text: What type of measure is communication complexity not an example of?, doc_tokens: [Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.]
# 5ad54b035b96ef001a10ac56 What type of measure is communication complexity not an example of? None
# qas_id: 56e1b8f3e3433e14004230e6, question_text: What are the three primary expressions used to represent case complexity?, doc_tokens: [The best, worst and average case complexity refer to three different ways of measuring the time complexity (or any other complexity measure) of different inputs of the same size. Since some inputs of size n may be faster to solve than others, we define the following complexities:]
# 56e1b8f3e3433e14004230e6 What are the three primary expressions used to represent case complexity? None
# qas_id: 56e1b8f3e3433e14004230e7, question_text: Case complexity likelihoods provide variable probabilities of what general measure? , doc_tokens: [The best, worst and average case complexity refer to three different ways of measuring the time complexity (or any other complexity measure) of different inputs of the same size. Since some inputs of size n may be faster to solve than others, we define the following complexities:]
# 56e1b8f3e3433e14004230e7 Case complexity likelihoods provide variable probabilities of what general measure?  None
# qas_id: 56e1b8f3e3433e14004230e8, question_text: What is one common example of a critical complexity measure?, doc_tokens: [The best, worst and average case complexity refer to three different ways of measuring the time complexity (or any other complexity measure) of different inputs of the same size. Since some inputs of size n may be faster to solve than others, we define the following complexities:]
# 56e1b8f3e3433e14004230e8 What is one common example of a critical complexity measure? None
# ...
# 5a38b819a4b263001a8c18c7 What did energy security do on an international level? None
# qas_id: 5a38b819a4b263001a8c18c8, question_text: What problem consists of trying to increase oil supplies and threats to US energy security?, doc_tokens: [The embargo had a negative influence on the US economy by causing immediate demands to address the threats to U.S. energy security. On an international level, the price increases changed competitive positions in many industries, such as automobiles. Macroeconomic problems consisted of both inflationary and deflationary impacts. The embargo left oil companies searching for new ways to increase oil supplies, even in rugged terrain such as the Arctic. Finding oil and developing new fields usually required five to ten years before significant production.]
# 5a38b819a4b263001a8c18c8 What problem consists of trying to increase oil supplies and threats to US energy security? None
# qas_id: 5a38b819a4b263001a8c18c9, question_text: What did macroeconomic problems cause oil companies to search for?, doc_tokens: [The embargo had a negative influence on the US economy by causing immediate demands to address the threats to U.S. energy security. On an international level, the price increases changed competitive positions in many industries, such as automobiles. Macroeconomic problems consisted of both inflationary and deflationary impacts. The embargo left oil companies searching for new ways to increase oil supplies, even in rugged terrain such as the Arctic. Finding oil and developing new fields usually required five to ten years before significant production.]
# 5a38b819a4b263001a8c18c9 What did macroeconomic problems cause oil companies to search for? None
# qas_id: 5726487b5951b619008f6edd, question_text: Which country faced a complete embargo in the EEC?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5726487b5951b619008f6edd Which country faced a complete embargo in the EEC? None
# qas_id: 5726487b5951b619008f6ede, question_text: The UK and France had non interruptions in their oil supply as they did not allow which country to use their airfield?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5726487b5951b619008f6ede The UK and France had non interruptions in their oil supply as they did not allow which country to use their airfield? None
# qas_id: 5726487b5951b619008f6edf, question_text: Which country is a traditional ally of Israel?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5726487b5951b619008f6edf Which country is a traditional ally of Israel? None
# qas_id: 5726487b5951b619008f6ee0, question_text: Harold WInston's supported which country's during its six day war?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5726487b5951b619008f6ee0 Harold WInston's supported which country's during its six day war? None
# qas_id: 5726487b5951b619008f6ee1, question_text: Who wanted Israel to withdraw from its border?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5726487b5951b619008f6ee1 Who wanted Israel to withdraw from its border? None
# qas_id: 5a38b9b3a4b263001a8c18cf, question_text: What was the embargo like in Israel?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5a38b9b3a4b263001a8c18cf What was the embargo like in Israel? None
# qas_id: 5a38b9b3a4b263001a8c18d0, question_text: What did the Netherlands not let America use during the embargo?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5a38b9b3a4b263001a8c18d0 What did the Netherlands not let America use during the embargo? None
# qas_id: 5a38b9b3a4b263001a8c18d1, question_text: Who did the EEC support during the Six-Day War?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5a38b9b3a4b263001a8c18d1 Who did the EEC support during the Six-Day War? None
# qas_id: 5a38b9b3a4b263001a8c18d2, question_text: Who is France a traditional ally of?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5a38b9b3a4b263001a8c18d2 Who is France a traditional ally of? None
# qas_id: 5a38b9b3a4b263001a8c18d3, question_text: What did Harold Wilson call for Israel to do in 1970?, doc_tokens: [The embargo was not uniform across Europe. Of the nine members of the European Economic Community (EEC), the Netherlands faced a complete embargo, the UK and France received almost uninterrupted supplies (having refused to allow America to use their airfields and embargoed arms and supplies to both the Arabs and the Israelis), while the other six faced partial cutbacks. The UK had traditionally been an ally of Israel, and Harold Wilson's government supported the Israelis during the Six-Day War. His successor, Ted Heath, reversed this policy in 1970, calling for Israel to withdraw to its pre-1967 borders.]
# 5a38b9b3a4b263001a8c18d3 What did Harold Wilson call for Israel to do in 1970? None
# qas_id: 572649d8f1498d1400e8db36, question_text: Which country is not badly hit by the embargo?, doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# 572649d8f1498d1400e8db36 Which country is not badly hit by the embargo? None
# qas_id: 572649d8f1498d1400e8db37, question_text: What caused UK to have an oil crisis in its own country?, doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# 572649d8f1498d1400e8db37 What caused UK to have an oil crisis in its own country? None
# qas_id: 572649d8f1498d1400e8db38, question_text: When did the series of strikes happen?, doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# 572649d8f1498d1400e8db38 When did the series of strikes happen? None
# qas_id: 572649d8f1498d1400e8db39, question_text: Name one country that banned boating, driving and flying on Sundays., doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# 572649d8f1498d1400e8db39 Name one country that banned boating, driving and flying on Sundays. None
# qas_id: 572649d8f1498d1400e8db3a, question_text: Which country rationed gasoline and heating gas?, doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# 572649d8f1498d1400e8db3a Which country rationed gasoline and heating gas? None
# qas_id: 5a38baa2a4b263001a8c18d9, question_text: What did the UK ban on Sundays due to the embargo?, doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# 5a38baa2a4b263001a8c18d9 What did the UK ban on Sundays due to the embargo? None
# qas_id: 5a38baa2a4b263001a8c18da, question_text: What was rationed by railroad workers?, doc_tokens: [Despite being relatively unaffected by the embargo, the UK nonetheless faced an oil crisis of its own - a series of strikes by coal miners and railroad workers over the winter of 1973–74 became a major factor in the change of government. Heath asked the British to heat only one room in their houses over the winter. The UK, Germany, Italy, Switzerland and Norway banned flying, driving and boating on Sundays. Sweden rationed gasoline and heating oil. The Netherlands imposed prison sentences for those who used more than their ration of electricity.]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
